# %%
import pandas as pd
import warnings

# %%
poverty_data = pd.read_csv("API_SI/API_SI.POV.DDAY_DS2_en_csv_v2_3359022.csv", skiprows = 3)

# %%
poverty_data[1:5]
# Out:
#                   Country Name Country Code  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name Indicator Code  1960  \
# 1  Poverty headcount ratio at $1.90 a day (2011 P...    SI.POV.DDAY   NaN
# 2  Poverty headcount ratio at $1.90 a day (2011 P...    SI.POV.DDAY   NaN
# 3  Poverty headcount ratio at $1.90 a day (2011 P...    SI.POV.DDAY   NaN
# 4  Poverty headcount ratio at $1.90 a day (2011 P...    SI.POV.DDAY   NaN
#
#    1961  1962  1963  1964  1965  ...  2012  2013  2014  2015  2016  2017  \
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
poverty_data.drop("Unnamed: 65", axis = 1, inplace = True)

# %%
poverty_data
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                         Indicator Name Indicator Code  1960  \
# 0    Poverty headcount ratio at $1.90 a day (2011 P...    SI.POV.DDAY   NaN
# 1    Poverty headcount ratio at $1.90 a day (2011 P...    SI.POV.DDAY   NaN
# 2    Poverty headcount ratio at $1.90 a day (2011 P...    SI.POV.DDAY   NaN
# 3    Poverty headcount ratio at $1.90 a day (2011 P...    SI.POV.DDAY   NaN
# ...

# %%
poverty_data.dropna(axis = 1, inplace = True, how = 'all')

# %%
poverty_data
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                         Indicator Name Indicator Code  1967  \
# 0    Poverty headcount ratio at $1.90 a day (2011 P...    SI.POV.DDAY   NaN
# 1    Poverty headcount ratio at $1.90 a day (2011 P...    SI.POV.DDAY   NaN
# 2    Poverty headcount ratio at $1.90 a day (2011 P...    SI.POV.DDAY   NaN
# 3    Poverty headcount ratio at $1.90 a day (2011 P...    SI.POV.DDAY   NaN
# ...
