# %%
import pandas as pd
import warnings
import sklearn

# %%
gdp_data = pd.read_csv("GDP-per-capita-dataset/GDP-dataset.csv", skiprows = 4)
gdp_data.head()
# Out:
#                   Country Name Country Code                    Indicator Name  \
# 0                        Aruba          ABW  GDP per capita growth (annual %)
# 1  Africa Eastern and Southern          AFE  GDP per capita growth (annual %)
# 2                  Afghanistan          AFG  GDP per capita growth (annual %)
# 3   Africa Western and Central          AFW  GDP per capita growth (annual %)
# 4                       Angola          AGO  GDP per capita growth (annual %)
#
#       Indicator Code  1960      1961      1962      1963      1964      1965  \
# 0  NY.GDP.PCAP.KD.ZG   NaN       NaN       NaN       NaN       NaN       NaN
# 1  NY.GDP.PCAP.KD.ZG   NaN -2.243254  5.269877  2.492519  1.896793  2.602103
# 2  NY.GDP.PCAP.KD.ZG   NaN       NaN       NaN       NaN       NaN       NaN
# 3  NY.GDP.PCAP.KD.ZG   NaN -0.232373  1.602307  4.990615  3.124672  1.783946
# 4  NY.GDP.PCAP.KD.ZG   NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
gdp_data.drop("Indicator Code", axis = 1, inplace = True)
gdp_data
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                        Indicator Name  1960      1961      1962      1963  \
# 0    GDP per capita growth (annual %)   NaN       NaN       NaN       NaN
# 1    GDP per capita growth (annual %)   NaN -2.243254  5.269877  2.492519
# 2    GDP per capita growth (annual %)   NaN       NaN       NaN       NaN
# 3    GDP per capita growth (annual %)   NaN -0.232373  1.602307  4.990615
# ...

# %%
poverty_data.drop("Unnamed: 65", axis = 1, inplace = True)
